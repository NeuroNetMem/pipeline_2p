# %%
import caiman as cm
import glob
import gc
import numpy as np
import matplotlib.pyplot as plt
from caiman.source_extraction.cnmf.cnmf import load_CNMF
from pathlib import Path
import pickle

import os
import sys
sys.path.append(os.path.abspath('../'))


import logreader.logreader as lr
import pipeline.functions as fs
import utils.utils as ut
# Out:
# 2023-09-26 15:33:02.997943: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Comparison between flickering and non flickering
# Use this notebook to load and inspect the raw tif video, preprocess it with a set of parameters and asses their effectiveness.

# %% [markdown]
# ## select session

# %%
data_path = Path("/ceph/imaging1/arie/test/20230920_screen_flickering_test_recording")
temp_output_path = Path('/scratch/dspalla/2p_data')

# %% [markdown]
# # Interactive visualization of the raw video

# %%
tif_files = glob.glob(str(data_path)+'/*.tif')
tif_on = tif_files[1]
tif_off = tif_files[2]
print(f'Reading file : \n {tif_on} \n {tif_off}')
# Out:
# Reading file :
#  /ceph/imaging1/arie/test/20230920_screen_flickering_test_recording/20230920_441412_screen_flickering_ON_00001.tif
#  /ceph/imaging1/arie/test/20230920_screen_flickering_test_recording/20230920_441412_screen_flickering_OFF_00001.tif

# %%
#movie = ut.read_tiff_slice(tif_file,start_frame=100,end_frame=1000)
movie_on = cm.load(tif_on)
movie_off = cm.load(tif_off)

# %%
movie_on = movie_on - np.min(movie_on) + 1

# %%
# make an image widget
from fastplotlib import ImageWidget, Plot, GridPlot
from ipywidgets import VBox, IntSlider, Layout

movies = [movie_off]

iw = ImageWidget(
    movies, 
    window_funcs={"t": (np.mean, 10)},
    vmin_vmax_sliders=True,
    cmap="jet"
)

iw.show()
# Out:
# RFBOutputContext()
# VBox(children=(JupyterWgpuCanvas(), IntSlider(value=0, description='dimension: t', max=14741), FloatRangeSlide…

# %%
movies = [movie_on]

iw = ImageWidget(
    movies, 
    window_funcs={"t": (np.mean, 10)},
    vmin_vmax_sliders=True,
    cmap="jet"
)

iw.show()
# Out:
# RFBOutputContext()
# VBox(children=(JupyterWgpuCanvas(), IntSlider(value=0, description='dimension: t', max=10483), FloatRangeSlide…

# %% [markdown]
# # Preprocess sessions
# Full pipeline preprocessing for a single session. All data (temporary and final outputs) is saved to the temp folder.

# %%
# PREPROCESSING STEPS
preprocess_vr_data = False
preprocess_2p_video = True

# %%
# PARAMETERS
neuron_radius = 6

compute_flags = {'correct_luminance':False,
                 'refit_cnmf':True,
                 'deconvolve' :True,
                 'detrend_df_f': True,
                 'n_processes': 5 #number of parallel processes.
                }

cropping_params = {'cropping_limits': [10,-10, 10,-10],
                   'cropping_times':[1000,10_000]}

mc_params = {# Caiman parameters
             'max_shifts': [20, 20],  #maximum allowed rigid shifts (in pixels)
             'num_frames_split':300,
             'strides': [48, 48], # start a new patch for pw-rigid motion correction every x pixels
             'overlaps': [24, 24], # overlap between pathes (size of patch strides+overlaps)
             'max_deviation_rigid': 5,  # maximum allowed shifts from rigid template (in pixels)
             'border_nan': 'copy',
             'pw_rigid': True, # flag for performing non-rigid motion correction
             'use_cuda': True,
             'gSig_filt': [neuron_radius,neuron_radius]}

# metrics to compute on motion corrected video
metrics_params = ['mean_image','frame_average','corr_image']

cnmf_params  = {'fr': 30, # framerate of the video, very important!
                'p': 1,   # order of autoregressive process contstraint
                'nb': 2,  # number of backround components       
                'merge_thr': 0.85, # correlation th to merge to sources
                'rf': 20,    # half-size of patch in pixels
                'stride': 2*neuron_radius, # "overlap between patches in pixels, should be roughly neuron diameter
                'K': 6,      # number of neurons per pathc
                'gSig': [neuron_radius, neuron_radius], # half-size of neuron in pixels (row,columns)
                'ssub': 1, # spatial compression, if larger than one compresses
                'tsub': 1, # temporal compression, if larger than one compresses
                'method_init': 'greedy_roi',
                'min_SNR': 5,  # min snr for good components, used in an OR rule with min_cnn_thr and rval_thr
                 #'min_SNR_reject': 3.0, # min snr for good components, used in an AND rule with min_cnn_lowest and r_values_lowest
                'rval_thr': 0.7, # spatial footprint consistency
                'use_cnn': True,
                'min_cnn_thr': 0.9,
                #'cnn_lowest': 0.9,
                'decay_time': 0.4,
                }
df_f_params = {'quantileMin':8,
               'frames_window':250       
                }

parameters = {'compute_flags': compute_flags,
              'cropping_params':cropping_params,
              'mc_params': mc_params,
              'metrics_params':metrics_params,
              'cnmf_params': cnmf_params,
              'df_f_params':df_f_params
                }

# %%
tif_file = tif_off
#make temp dir
temp_path = temp_output_path.joinpath('flickering_off')
Path(temp_path).mkdir(parents=True, exist_ok=True)


#Decode log and process behaviour
if preprocess_vr_data:
    try:
        vr_data = lr.preprocess_vr_data(tif_file = tif_file, log_file=log_file)
        lr.save_processed_vr_data(temp_path,vr_data)
    except:
        print(f'Error in session {animal}_{date}, skipping ...')

#Run caiman pipeline 
if preprocess_2p_video:
    fs.preprocess_video(input_video=tif_file,
                    output_folder=temp_path,
                    parameters=parameters,
                    temp_folder=temp_path,
                    keep_temp_folder = True)
# Out:
# Cropping movie ...
# temp file saved
# Motion-correcting movie ...
# Starting CaImAn server
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Renaming motion corrected file ...
# Computing metrics on motion corrected video
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Converting motion corrected file in C order...
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# Running source extraction ...
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
#
#
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Refitting cnmf ...
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Evaluating components ...
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_C_frames_14741.mmap
# GPU run not requested, disabling use of GPUs
# USING MODEL (keras API): /home/dspalla/caiman_data/model/cnn_model.json
# 7/7 [==============================] - 0s 35ms/step
# Deconvolve components
# Extract df/f
# Savign CNMF object in hdf5
# Saving neural data for downstream analysis @/scratch/dspalla/2p_data/flickering_off
#   0%|          | 0/14742 [00:00<?, ?it/s]
# Done

# %%
tif_file = tif_on
#make temp dir
temp_path = temp_output_path.joinpath('flickering_on')
Path(temp_path).mkdir(parents=True, exist_ok=True)


#Decode log and process behaviour
if preprocess_vr_data:
    try:
        vr_data = lr.preprocess_vr_data(tif_file = tif_file, log_file=log_file)
        lr.save_processed_vr_data(temp_path,vr_data)
    except:
        print(f'Error in session {animal}_{date}, skipping ...')

#Run caiman pipeline 
if preprocess_2p_video:
    fs.preprocess_video(input_video=tif_file,
                    output_folder=temp_path,
                    parameters=parameters,
                    temp_folder=temp_path,
                    keep_temp_folder = True)
# Out:
# Cropping movie ...
# temp file saved
# Motion-correcting movie ...
# Starting CaImAn server
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# WARNING:root:Movie average is negative. Removing 1st percentile.
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Renaming motion corrected file ...
# Computing metrics on motion corrected video
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Converting motion corrected file in C order...
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Running source extraction ...
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
#
#
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmapDecode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
#
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Refitting cnmf ...
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Evaluating components ...
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# WARNING:root:Component 1 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# WARNING:root:Component 4 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# WARNING:root:Component 39 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# WARNING:root:Component 37 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# WARNING:root:Component 49 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# WARNING:root:Component 3 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# WARNING:root:Component 10 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# WARNING:root:Component 15 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# WARNING:root:Component 38 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# WARNING:root:Component 32 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# WARNING:root:Component 41 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# WARNING:root:Component 4 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# WARNING:root:Component 27 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# WARNING:root:Component 39 is only active jointly with neighboring components. Space correlation calculation might be unreliable.
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_C_frames_9000.mmap
# GPU run not requested, disabling use of GPUs
# USING MODEL (keras API): /home/dspalla/caiman_data/model/cnn_model.json
# 26/26 [==============================] - 1s 23ms/step
# Deconvolve components
# Extract df/f
# Savign CNMF object in hdf5
# Saving neural data for downstream analysis @/scratch/dspalla/2p_data/flickering_on
#   0%|          | 0/10484 [00:00<?, ?it/s]
# frame_ts with len 10484 incompatible with traces with len 9000
#  defaulting to 29.94 Hz timestamps.
# Done

# %% [markdown]
# # Visualize preprocessed session

# %% [markdown]
# ## Summary images and metrics

# %%
# flickering oFF
temp_path = temp_output_path.joinpath('flickering_off')

metrics_file = temp_path.joinpath('metrics.pickle')
with open(metrics_file,'rb') as file:
    metrics = pickle.load(file)


plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Mean image')
plt.imshow(metrics['mean_image'],cmap=plt.cm.gnuplot2)

plt.subplot(1,2,2)
plt.title('Corr image')
x = metrics['corr_image']
plt.imshow(x,vmin=np.percentile(x.ravel(),3),vmax=np.percentile(x.ravel(),97),
           cmap=plt.cm.gnuplot2)

plt.figure(figsize=(20,5))
plt.plot(metrics['frame_average'])
#plt.ylim([0.9,1.1])


plt.tight_layout()

# flickering ON
temp_path = temp_output_path.joinpath('flickering_on')

metrics_file = temp_path.joinpath('metrics.pickle')
with open(metrics_file,'rb') as file:
    metrics = pickle.load(file)


plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Mean image')
plt.imshow(metrics['mean_image'],cmap=plt.cm.gnuplot2)

plt.subplot(1,2,2)
plt.title('Corr image')
x = metrics['corr_image']
plt.imshow(x,vmin=np.percentile(x.ravel(),3),vmax=np.percentile(x.ravel(),97),
           cmap=plt.cm.gnuplot2)

plt.figure(figsize=(20,5))
plt.plot(metrics['frame_average'])
#plt.ylim([0.9,1.1])


plt.tight_layout()

# %%
plt.matshow(x[:100,:100])
plt.axvline(x=34)
plt.axvline(x=46)

# %% [markdown]
# ## Interactive video, flickering off

# %%
temp_path = temp_output_path.joinpath('flickering_off')
cropped_file = glob.glob(str(temp_path)+'/cropped*.mmap')[0]
mcorr_file = glob.glob(str(temp_path)+'/mcorr*.mmap')[0]
#print(tif_file)
print(cropped_file)
print(mcorr_file)
# Out:
# /scratch/dspalla/2p_data/flickering_off/cropped_d1_492_d2_492_d3_1_order_F_frames_14741.mmap
# /scratch/dspalla/2p_data/flickering_off/mcorr_d1_492_d2_492_d3_1_order_F_frames_14741.mmap

# %%
cropped_movie = cm.load(cropped_file)
mcorr_movie = cm.load(mcorr_file)

# make an image widget
from fastplotlib import ImageWidget, Plot, GridPlot
from ipywidgets import VBox, IntSlider, Layout

movies = [cropped_movie,mcorr_movie]

iw = ImageWidget(
    movies, 
    window_funcs={"t": (np.mean, 100)},
    vmin_vmax_sliders=True,
    cmap="jet"
)

iw.show()
# Out:
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# RFBOutputContext()
# VBox(children=(JupyterWgpuCanvas(), IntSlider(value=0, description='dimension: t', max=8999), FloatRangeSlider…

# %% [markdown]
# ## Interactive video, flickering on

# %%
temp_path = temp_output_path.joinpath('flickering_on')
cropped_file = glob.glob(str(temp_path)+'/cropped*.mmap')[0]
mcorr_file = glob.glob(str(temp_path)+'/mcorr*.mmap')[0]
#print(tif_file)
print(cropped_file)
print(mcorr_file)
# Out:
# /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_F_frames_9000.mmap

# %%
cropped_movie = cm.load(cropped_file)
mcorr_movie = cm.load(mcorr_file)

# make an image widget
from fastplotlib import ImageWidget, Plot, GridPlot
from ipywidgets import VBox, IntSlider, Layout

movies = [cropped_movie,mcorr_movie]

iw = ImageWidget(
    movies, 
    window_funcs={"t": (np.mean, 100)},
    vmin_vmax_sliders=True,
    cmap="jet"
)

iw.show()
# Out:
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/cropped_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_F_frames_9000.mmap
# RFBOutputContext()
# VBox(children=(JupyterWgpuCanvas(), IntSlider(value=0, description='dimension: t', max=8999), FloatRangeSlider…

# %% [markdown]
# # Extractred compontents

# %%
temp_path = temp_output_path.joinpath('flickering_off')


metrics_file = temp_path.joinpath('metrics.pickle')
with open(metrics_file,'rb') as file:
    metrics = pickle.load(file)

cnmf_file = temp_path.joinpath('cnmf.hdf5')
cnmf = load_CNMF(cnmf_file)
ests = cnmf.estimates

print(f'total # of components:{len(ests.idx_components)+len(ests.idx_components_bad)}')
print(f'GOOD components:{len(ests.idx_components)}')
print(f'BAD components:{len(ests.idx_components_bad)}')
# Out:
# total # of components:224
# GOOD components:16
# BAD components:208

# %%
ests.plot_contours(img=np.asarray(metrics['corr_image']),idx=ests.idx_components,cmap=plt.cm.gnuplot2)

# %%
temp_path = temp_output_path.joinpath('flickering_on')

metrics_file = temp_path.joinpath('metrics.pickle')
with open(metrics_file,'rb') as file:
    metrics = pickle.load(file)

cnmf_file = temp_path.joinpath('cnmf.hdf5')
cnmf = load_CNMF(cnmf_file)
ests = cnmf.estimates

print(f'total # of components:{len(ests.idx_components)+len(ests.idx_components_bad)}')
print(f'GOOD components:{len(ests.idx_components)}')
print(f'BAD components:{len(ests.idx_components_bad)}')
# Out:
# total # of components:826
# GOOD components:366
# BAD components:460

# %%
ests.plot_contours(img=np.asarray(metrics['corr_image']),idx=ests.idx_components,cmap=plt.cm.gnuplot2)

# %% [markdown]
# ### Plot timecourses and footprints examples

# %%
from ipywidgets import interact
import ipywidgets as widgets

def plot_unit(i,min_time,max_time):
    
    good_traces = ests.C[ests.idx_components]
    good_footprints = ests.A[:,ests.idx_components].toarray()

    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.title(f'neuron {i}')
    plt.imshow(good_footprints[:,i].reshape(ests.dims),cmap=plt.cm.gnuplot2)
    
    plt.subplot(1,2,2)
    plt.plot(np.arange(min_time,max_time),good_traces[i,min_time:max_time])
    
    
    plt.tight_layout()
    
    
    
interact(plot_unit, i = widgets.IntSlider(min=0, max=(len(ests.idx_components)-1), value=0),
                    min_time =widgets.IntSlider(min=0, max=ests.C.shape[1]-1, value=0),
                    max_time = widgets.IntSlider(min=0, max=ests.C.shape[1]-1, value=10000)
         )
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=365), IntSlider(value=0, description='min_time',…
# <function __main__.plot_unit(i, min_time, max_time)>

# %% [markdown]
# ### Make and display reconstructed video

# %%
# memory intensive
movie_len = 2000
r_mov = ests.A[:,ests.idx_components]@ests.C[ests.idx_components,:movie_len]
r_mov = r_mov.reshape(ests.dims + (-1,), order='F')
r_mov = np.transpose(r_mov,(2,0,1))

# %%
r_mov.shape
# Out:
# (2000, 492, 492)

# %%
mcorr_file = glob.glob(str(temp_path)+'/mcorr*.mmap')[0]
mcorr_movie = cm.load(mcorr_file)[:movie_len]
# Out:
# Decode mmap filename /scratch/dspalla/2p_data/flickering_on/mcorr_d1_492_d2_492_d3_1_order_F_frames_9000.mmap

# %%
from fastplotlib import ImageWidget, Plot, GridPlot
from ipywidgets import VBox, IntSlider, Layout

iw = ImageWidget(
    [mcorr_movie,r_mov], 
    window_funcs={"t": (np.mean, 10)},
    vmin_vmax_sliders=True,
    cmap='jet'
)



iw.show()
# Out:
# RFBOutputContext()
# VBox(children=(JupyterWgpuCanvas(), IntSlider(value=0, description='dimension: t', max=1999), FloatRangeSlider…

# %%
iw.plot.canvas.close()

# %%
n_data_file= temp_path.joinpath('neural_data.pickle')
with open(n_data_file,'rb') as file:
    n_data = pickle.load(file)

# %%
n_data.keys()
# Out:
# dict_keys(['traces', 'footprints', 'df_f', 'deconvolved', 'positions', 'contour', 'frame_ts'])

# %%
len(n_data['frame_ts'][n_data['deconvolved'][0]])
# Out:
# 3097

# %% [markdown]
# # Component quality distribution

# %% [markdown]
# ### SNR and CNN confidence distributions

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,3,1)
plt.hist(ests.SNR_comp,bins=50);
plt.xlabel('SNR')
plt.subplot(1,3,2)
plt.hist(ests.cnn_preds,bins=50);
plt.xlabel('cnn confidence')
plt.subplot(1,3,3)
plt.hist(ests.r_values,bins=50);
plt.xlabel('space correlations')
# Out:
# Text(0.5, 0, 'space correlations')

# %% [markdown]
# ### Sensitivity analysis
# Plots the number of components accepted as good for varyig thresholds

# %%
ths_cnn = np.linspace(0,1)
ths_snr = np.linspace(min(ests.SNR_comp),max(ests.SNR_comp))


good_sources_cnn = []
good_sources_snr = []

for th_cnn,th_snr in zip(ths_cnn,ths_snr):
    good_sources_cnn.append(np.sum(ests.cnn_preds>th_cnn))
    good_sources_snr.append(np.sum(ests.SNR_comp>th_snr))

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(ths_cnn,good_sources_cnn)
plt.xlabel('confidence th')
plt.ylabel('# of good sources')
plt.subplot(1,2,2)
plt.plot(ths_cnn[:-1],abs(np.diff(good_sources_cnn)))
plt.xlabel('confidence th')
plt.ylabel('sensitivity')
plt.tight_layout()

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(ths_snr,good_sources_snr)
plt.xlabel('confidence th')
plt.ylabel('# of good sources')
plt.subplot(1,2,2)
plt.plot(ths_snr[:-1],abs(np.diff(good_sources_snr)))
max_sens = ths_snr[np.argmax(abs(np.diff(good_sources_snr)))]
plt.axvline(x=max_sens,label=f'max ={max_sens}',c='r')
plt.legend()
plt.xlabel('confidence th')
plt.ylabel('sensitivity')
plt.tight_layout()

# %% [markdown]
# # Save session parameters
# Save preprocessing parameters in the folder preprocessing_params in the raw data path. These parameters will be read by the batch preprocesser when iterating over session together. When no parameters are found for a session, the default (stored in default_parameters) will be used.

# %%
 ## save parameters
import yaml 
    
# redefine corpping for whole video
cropping_params = {'cropping_limits': [10,-10, 10,-10],
                   'cropping_times':[0,-1]}

parameters['cropping_params'] = cropping_params
    
        
with open(Path(raw_data_path).joinpath(f'preprocess_params/parameters_{animal}_{date}.yml'),'w') as file:
    yaml.dump(parameters,file)

# %%
with open(Path(raw_data_path).joinpath(f'preprocess_params/default_parameters.yml'),'w') as file:
    yaml.dump(parameters,file)

# %% [markdown]
# # clean temp directory
# delete the temporary directory to free disk space

# %%
/ceph/imaging1/arie/preprocess_params
