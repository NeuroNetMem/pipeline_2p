# %% [markdown]
# # Tracking cells across sessions
# This notebook contains code for the tracking of neurons across different sessions and analysis to asses its feasibility.
#
# - **Pairwise session tracking** lets the user analyze a specific pair of sessions, and look at them in details
# - **Multiple sessions tracking** performs the tracking on a list of sessions, and contains code for analysis to assess the quality of the tracking with different metrics on the overall list
# - **Pairwise matching distribution** performs registration on all possible pairs in the given list of sessions and comutes metrics distributions.

# %%
import pickle
from caiman.base.rois import register_multisession
from caiman.utils import visualization
from caiman.source_extraction.cnmf.cnmf import load_CNMF
from pathlib import Path
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# 2023-07-25 13:28:45.104753: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Pairwise session tracking

# %%
data_path = Path("/ceph/imaging1/davide/2p_data/eq_luminance/")

# SESSION TO PREPROCESS
#sessions = {'441406_fiano':['20230301','20230306']}
sessions = {'441394_ribolla':['20230301','20230306']}

# %%
spatial = []
dims = []
templates = []
for animal in sessions.keys():
    for date in sessions[animal]:
        
        cnmf = load_CNMF(data_path.joinpath(f'{animal}/{date}/cnmf.hdf5'))
        with open(data_path.joinpath(f'{animal}/{date}/metrics.pickle'),'rb') as pfile:
            metrics = pickle.load(pfile)
        spatial.append(cnmf.estimates.A[:,cnmf.estimates.idx_components])
        dims.append(cnmf.dims)
        templates.append(np.asarray(metrics['corr_image']))

# %%
plt.figure(figsize=(10,5))
for i,t in enumerate(templates):
    plt.subplot(1,len(templates),i+1)
    plt.imshow(t,vmin=np.percentile(t.ravel(),3),vmax=np.percentile(t.ravel(),97),cmap=plt.cm.gnuplot2)

# %%
spatial_union, assignments, matchings = register_multisession(A=spatial, dims=dims[0], templates=templates)
# Out:
# /scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
disjoint_union = spatial[0].shape[1]+spatial[1].shape[1]
n_matched = disjoint_union-spatial_union.shape[1]
max_matchable = min(spatial[0].shape[1],spatial[1].shape[1])
print(f'Disjoint union: {disjoint_union}')
print(f'Spatial union:{spatial_union.shape[1]}')
print(f'Number matched:{n_matched}')
print(f'Fraction matched: {n_matched/max_matchable}')
# Out:
# Disjoint union: 130
# Spatial union:127
# Number matched:3
# Fraction matched: 0.057692307692307696

# %% [markdown]
# # Multiple session tracking

# %%
data_path = Path("/ceph/imaging1/davide/2p_data/eq_luminance/")
sessions = {'441406_fiano':['20230301','20230306','20230307','20230308','20230309','20230315','20230316','20230317','20230320','20230321'],
            '441394_ribolla':['20230301','20230306','20230307','20230308','20230309','20230315','20230316','20230317','20230320','20230321']
           }

# %%
spatial = []
dims = []
templates = []
animal = '441394_ribolla'
for date in sessions[animal]:

    cnmf = load_CNMF(data_path.joinpath(f'{animal}/{date}/cnmf.hdf5'))
    with open(data_path.joinpath(f'{animal}/{date}/metrics.pickle'),'rb') as pfile:
        metrics = pickle.load(pfile)
    spatial.append(cnmf.estimates.A[:,cnmf.estimates.idx_components])
    dims.append(cnmf.dims)
    templates.append(np.asarray(metrics['mean_image']))

# %%
plt.figure(figsize=(10,5))
for i,t in enumerate(templates):
    plt.subplot(2,5,i+1)
    plt.title(f'{sessions[animal][i]}')
    plt.imshow(t,cmap=plt.cm.gnuplot2)
    plt.axis('off')
plt.tight_layout()
#plt.savefig(f'/ceph/imaging1/davide/2p_data/images/corr_imgs_{animal}.png')

# %%
spatial_union, assignments, matchings = register_multisession(A=spatial, dims=dims[0], templates=templates)
# Out:
# /scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
cell_frequency = np.sum(~np.isnan(assignments), axis=1)
plt.figure(figsize=(5,5))
plt.title(f'{animal}')
sns.histplot(cell_frequency)
plt.xlabel('# of session in which cell is present')
sns.despine()

# %%
registered_cells = []
ns = np.arange(1,11)

for n in ns:
    registered_cells.append(np.sum(cell_frequency>n))

plt.figure(figsize=(5,5))
plt.title(f'{animal}')
plt.plot(ns,registered_cells)
plt.xlabel('# of sessions')
plt.ylabel('# of cells')
sns.despine()

# %% [markdown]
# # Pairwise matching distirbution

# %%
def compute_matched_fraction(session1,session2):
    
    cnmf1 = load_CNMF(f'{session1}/cnmf.hdf5')
    with open(f'{session1}/metrics.pickle','rb') as pfile:
            metrics1 = pickle.load(pfile)
            
    cnmf2 = load_CNMF(f'{session2}/cnmf.hdf5')
    with open(f'{session2}/metrics.pickle','rb') as pfile:
            metrics2 = pickle.load(pfile)
    
    
    
    A = [cnmf1.estimates.A[:,cnmf1.estimates.idx_components],cnmf2.estimates.A[:,cnmf2.estimates.idx_components]]
    dims = [cnmf1.dims,cnmf2.dims]
    templates = [np.asarray(metrics1['mean_image']),np.asarray(metrics2['mean_image'])]
    spatial_union, assignments, matchings = register_multisession(A=A, dims=dims[0], templates=templates)
    
    disjoint_union = A[0].shape[1]+A[1].shape[1]
    n_matched = disjoint_union-spatial_union.shape[1]
    max_matchable = min(A[0].shape[1],A[1].shape[1])
    
    
    return n_matched/max_matchable

# %%
data_path = Path("/ceph/imaging1/davide/2p_data/eq_luminance/")
sessions = {'441406_fiano':['20230301','20230306','20230307','20230308','20230309','20230315','20230316','20230317','20230320','20230321'],
            '441394_ribolla':['20230301','20230306','20230307','20230308','20230309','20230315','20230316','20230317','20230320','20230321']
           }

# %%
from itertools import combinations
from tqdm import tqdm

animal = '441394_ribolla'

dates = sessions[animal]

matched_fraction = []
for date1,date2 in tqdm(combinations(dates,2)):
    session1 = data_path.joinpath(f'{animal}/{date1}')
    session2 = data_path.joinpath(f'{animal}/{date2}')
    matched_fraction.append(compute_matched_fraction(session1,session2))
# Out:
# 0it [00:00, ?it/s]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 1it [00:02,  2.55s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 2it [00:05,  2.78s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 3it [00:10,  4.01s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 4it [00:16,  4.67s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 5it [00:22,  4.98s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 6it [00:26,  4.78s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 7it [00:31,  4.98s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 8it [00:36,  4.94s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 9it [00:42,  5.09s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 10it [00:46,  4.72s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 11it [00:52,  5.18s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 12it [00:59,  5.69s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 13it [01:05,  5.96s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 14it [01:11,  5.76s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 15it [01:17,  6.02s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 16it [01:23,  6.03s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 17it [01:30,  6.31s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 18it [01:37,  6.32s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 19it [01:44,  6.53s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 21it [01:56,  6.32s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 22it [02:03,  6.45s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 23it [02:09,  6.34s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 24it [02:16,  6.45s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 25it [02:26,  7.54s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/caiman/base/rois.py:87: RuntimeWarning: invalid value encountered in divide
#   cm = (Coor * A / A.sum(axis=0)).T
# /scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 26it [02:36,  8.27s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 27it [02:44,  8.19s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 28it [02:54,  8.98s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 29it [03:04,  9.19s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 30it [03:15,  9.58s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 31it [03:25,  9.68s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 32it [03:33,  9.35s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 33it [03:43,  9.58s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 34it [03:53,  9.53s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 35it [04:03,  9.71s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 36it [04:11,  9.36s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 37it [04:22,  9.84s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 38it [04:32,  9.86s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 39it [04:43, 10.06s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 40it [04:51,  9.54s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 41it [04:59,  8.97s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 42it [05:07,  8.75s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 43it [05:19,  9.74s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 44it [05:32, 10.64s/it]/scratch/dspalla/mambaforge/envs/mescore/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 45it [05:43,  7.62s/it]

# %%
import seaborn as sns
plt.figure(figsize=(5,5))
plt.title(f'{animal}')
sns.histplot(matched_fraction);
sns.despine()
plt.xlabel('Fraction of matched cells')
plt.savefig(f'/ceph/imaging1/davide/2p_data/images/matched_frac_eq_lum_{animal}.png')

# %%
import yaml

# %%
filename = '/ceph/imaging1/arie/preprocess_params/default_parameters.yml'

# %%
# Program to convert yaml file to dictionary
import yaml
# opening a file
with open(filename, 'r') as stream:
    try:
    # Converts yaml document to python object
        d=yaml.safe_load(stream)

    # Printing dictionary
        print(d)
    except yaml.YAMLError as e:
        print(e)
# Out:
# {'cnmf_params': {'K': 6, 'cnn_lowest': 0.9, 'decay_time': 0.4, 'fr': 30, 'gSig': [6, 6], 'merge_thr': 0.85, 'method_init': 'greedy_roi', 'min_SNR': 3.0, 'min_SNR_reject': 3.0, 'min_cnn_thr': 0.9, 'nb': 2, 'p': 1, 'rf': 20, 'rval_thr': 0.9, 'ssub': 1, 'stride': 12, 'tsub': 1, 'use_cnn': True}, 'compute_flags': {'correct_luminance': False, 'deconvolve': True, 'detrend_df_f': True, 'n_processes': 5, 'refit_cnmf': True}, 'cropping_params': {'cropping_limits': [10, -10, 10, -10], 'cropping_times': [0, -1]}, 'df_f_params': {'frames_window': 250, 'quantileMin': 8}, 'mc_params': {'border_nan': 'copy', 'gSig_filt': None, 'max_deviation_rigid': 5, 'max_shifts': [20, 20], 'num_frames_split': 300, 'overlaps': [24, 24], 'pw_rigid': True, 'strides': [48, 48], 'use_cuda': True}, 'metrics_params': ['mean_image', 'frame_average', 'corr_image']}
